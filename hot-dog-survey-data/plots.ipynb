# %% [markdown]
# <a href="https://colab.research.google.com/github/nishanadahal/DS-4002/blob/spring-2026_section-001/hot-dog-survey-data/plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


hot_dog_data = pd.read_excel("hotdogdata.xlsx")

hot_dog_data.info()
counts = hot_dog_data['Is a Hotdog a Sandwich?'].value_counts()
counts.plot.pie()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 7 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Timestamp                                             190 non-null    datetime64[ns]
#  1   Year at UVA                                           190 non-null    object
#  2   What is your Gender Identity?                         190 non-null    object
#  3   What Schools are you a Part of?                       190 non-null    object
#  4   Is a Hotdog a Sandwich?                               190 non-null    object
#  5   How strongly do you feel about your previous answer?  190 non-null    int64
#  6   How frequently do you eat hot dogs?                   190 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 10.5+ KB
