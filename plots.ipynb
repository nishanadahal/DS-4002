# %% [markdown]
# <a href="https://colab.research.google.com/github/nishanadahal/DS-4002/blob/spring-2026_section-001/plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

hot_dog_data = pd.read_excel("hotdogdata.xlsx")
print(hot_dog_data.head())
# Out:
#                 Timestamp       Year at UVA What is your Gender Identity?  \
# 0 2026-01-14 13:51:44.672  Graduate Student                           Man
# 1 2026-01-14 13:53:31.309          3rd Year                         Woman
# 2 2026-01-14 13:53:34.682          3rd Year                         Woman
# 3 2026-01-14 13:55:42.453          4th Year                         Woman
# 4 2026-01-14 13:57:21.355          4th Year                         Woman
#
#   What Schools are you a Part of? Is a Hotdog a Sandwich?  \
# 0                    Data Science                     Yes
# 1                     Engineering                     Yes
# 2  Arts and Sciences, Engineering                     Yes
# 3                     Engineering                      No
# 4                     Engineering                     Yes
#
#    How strongly do you feel about your previous answer?  \
# 0                                                  1
# 1                                                  3
# ...
